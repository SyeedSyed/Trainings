# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import scipy.stats as s

# %%
dataset=pd.read_csv(r"D:\Data Science\sales_data.csv")

# %%
dataset
# Out:
#         User_ID Product_ID Gender    Age  Occupation       City  \
# 0       1000001  P00069042      F   0-17          10  Hyderabad
# 1       1000001  P00248942      F   0-17          10  Hyderabad
# 2       1000001  P00087842      F   0-17          10  Hyderabad
# 3       1000001  P00085442      F   0-17          10  Hyderabad
# 4       1000002  P00285442      M    55+          16    Chennai
# ...         ...        ...    ...    ...         ...        ...
# 550063  1006033  P00372445      M  51-55          13  Bangalore
# 550064  1006035  P00375436      F  26-35           1    Chennai
# 550065  1006036  P00375436      F  26-35          15  Bangalore
# 550066  1006038  P00375436      F    55+           1    Chennai
# 550067  1006039  P00371644      F  46-50           0  Bangalore
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dataset[["Gender","City"]]
# Out:
#        Gender       City
# 0           F  Hyderabad
# 1           F  Hyderabad
# 2           F  Hyderabad
# 3           F  Hyderabad
# 4           M    Chennai
# ...       ...        ...
# 550063      M  Bangalore
# 550064      F    Chennai
# 550065      F  Bangalore
# 550066      F    Chennai
# 550067      F  Bangalore
#
# [550068 rows x 2 columns]

# %% [markdown]
# ### Null Hypothesis(H0): There is no relationship between gender and city
#
# ### Alternate Hypothesis(H1): There is a relationship between gender and city

# %%
dataset
# Out:
#         User_ID Product_ID Gender    Age  Occupation       City  \
# 0       1000001  P00069042      F   0-17          10  Hyderabad
# 1       1000001  P00248942      F   0-17          10  Hyderabad
# 2       1000001  P00087842      F   0-17          10  Hyderabad
# 3       1000001  P00085442      F   0-17          10  Hyderabad
# 4       1000002  P00285442      M    55+          16    Chennai
# ...         ...        ...    ...    ...         ...        ...
# 550063  1006033  P00372445      M  51-55          13  Bangalore
# 550064  1006035  P00375436      F  26-35           1    Chennai
# 550065  1006036  P00375436      F  26-35          15  Bangalore
# 550066  1006038  P00375436      F    55+           1    Chennai
# 550067  1006039  P00371644      F  46-50           0  Bangalore
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# # Chi Square Test

# %%
sample_data=dataset.sample(n=10000)

# %%
sample_data
# Out:
#         User_ID Product_ID Gender    Age  Occupation       City  \
# 92236   1002153  P00085942      M  18-25          16  Bangalore
# 138316  1003401  P00259242      M  36-45           7  Bangalore
# 530712  1003747  P00014542      M  46-50          13    Chennai
# 457980  1004458   P0096342      F  26-35           4  Bangalore
# 523762  1002727  P00034042      M  26-35          11    Chennai
# ...         ...        ...    ...    ...         ...        ...
# 397660  1001204  P00258842      M  26-35           7  Bangalore
# 32937   1005054  P00176042      M  36-45           2  Bangalore
# 484064  1002576  P00059642      M  18-25          17  Bangalore
# 223210  1004386  P00357242      M  26-35           5  Bangalore
# 20833   1003301  P00239742      F  26-35           2  Bangalore
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 92236                           3               0                   2
# ...

# %%
pd.crosstab(sample_data["Gender"],sample_data["City"],margins=True,margins_name="Total")
# Out:
# City    Bangalore  Chennai  Hyderabad  Total
# Gender
# F            1059      750        655   2464
# M            3160     2383       1993   7536
# Total        4219     3133       2648  10000

# %%
observed_values=pd.crosstab(sample_data["Gender"],sample_data["City"])

# %%
observed_values
# Out:
# City    Bangalore  Chennai  Hyderabad
# Gender
# F            1059      750        655
# M            3160     2383       1993

# %%
#converts dataframe into numpy array
observed_values=observed_values.values

# %%
observed_values
# Out:
# array([[1059,  750,  655],
#        [3160, 2383, 1993]], dtype=int64)

# %%
#1 Calculated chi square value
#2 Calculated p value
#3 DOF--Degree of Freedom
#4--Expected Values
chi_cal,p,dof,expected_values=s.chi2_contingency(observed_values)

# %%
chi_cal
# Out:
# 1.3251457684578778

# %%
p
# Out:
# 0.5155232450872542

# %%
dof
# Out:
# 2

# %%
expected_values
# Out:
# array([[1039.5616,  771.9712,  652.4672],
#        [3179.4384, 2361.0288, 1995.5328]])

# %%
#Confidence 95%
#Significance Level -- 0.05

# %%
chi_cal
# Out:
# 1.3251457684578778

# %%
#Significance Level -- 0.05
#dof=2
chi_tab=5.99

# %%
if(chi_cal>chi_tab):
    print("Reject the Null Hypothesis")
    print("There is a relationship between gender and city")
else:
    print("Accept the Null Hypothesis")
    print("There is no relationship between gender and city")
# Out:
# Accept the Null Hypothesis
# There is no relationship between gender and city

# %% [markdown]
# ### We significantly prove that gender has no relationship with city

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3075b36c09c8> in <module>
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined
