# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"D:\Data Science\sales_data.csv")

# %%
dataset
# Out:
#         User_ID Product_ID Gender    Age  Occupation       City  \
# 0       1000001  P00069042      F   0-17          10  Hyderabad
# 1       1000001  P00248942      F   0-17          10  Hyderabad
# 2       1000001  P00087842      F   0-17          10  Hyderabad
# 3       1000001  P00085442      F   0-17          10  Hyderabad
# 4       1000002  P00285442      M    55+          16    Chennai
# ...         ...        ...    ...    ...         ...        ...
# 550063  1006033  P00372445      M  51-55          13  Bangalore
# 550064  1006035  P00375436      F  26-35           1    Chennai
# 550065  1006036  P00375436      F  26-35          15  Bangalore
# 550066  1006038  P00375436      F    55+           1    Chennai
# 550067  1006039  P00371644      F  46-50           0  Bangalore
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
dataset["Purchase"]
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
#           ...
# 550063      368
# 550064      371
# 550065      137
# 550066      365
# 550067      490
# Name: Purchase, Length: 550068, dtype: int64

# %% [markdown]
# # Step-1 Sampling

# %%
import random

# %%
random.choices(dataset["Purchase"],k=20)
# Out:
# [6992,
#  7111,
#  12110,
#  7056,
#  9716,
#  8124,
#  13225,
#  12862,
#  5992,
#  15251,
#  8086,
#  20396,
#  7174,
#  10989,
#  9849,
#  7790,
#  15761,
#  48,
#  2085,
#  8645]

# %%
#no of samples
n=50
#sample size
k=60

# %%
samples=[]
for i in range(0,n):
    samples.append(random.choices(dataset["Purchase"],k=k))

# %%
samples
# Out:
# [[604,
#   11860,
#   7921,
#   8861,
#   3472,
#   8083,
#   8657,
#   12259,
#   16404,
#   19493,
#   7962,
#   12319,
#   15795,
#   13099,
#   6854,
#   4028,
#   11553,
#   14414,
#   11922,
#   15441,
#   7879,
#   13240,
#   9749,
#   19428,
#   7655,
#   2948,
#   1490,
#   5412,
#   8626,
#   20359,
#   5913,
#   13278,
#   8659,
#   5492,
#   9799,
#   3885,
#   11519,
#   3635,
#   2098,
#   10127,
#   3569,
#   8714,
#   754,
#   6176,
#   6167,
#   5447,
#   8286,
#   20817,
#   566,
#   12776,
#   16091,
#   11500,
#   15751,
#   15942,
#   7906,
#   11402,
#   3898,
#   19000,
#   12984,
#   7951],
#  [20556,
#   19316,
#   5971,
#   3013,
#   7109,
#   10049,
#   7093,
#   5251,
#   13308,
#   19662,
#   11414,
#   8771,
#   20556,
#   6862,
#   3215,
#   19458,
#   2207,
#   13589,
#   20943,
#   7097,
#   8120,
#   19597,
#   11403,
#   15884,
#   16534,
#   5482,
#   6174,
#   15578,
#   5229,
#   3445,
#   5413,
#   5843,
#   2821,
#   11523,
#   8258,
#   7998,
# ...

# %%
sample_means=[]

# %%
for sample in samples:
    sample_means.append(np.mean(sample))

# %%
sample_means
# Out:
# [9631.483333333334,
#  10077.583333333334,
#  10265.4,
#  8742.666666666666,
#  9714.283333333333,
#  9145.883333333333,
#  9694.133333333333,
#  9077.9,
#  9302.233333333334,
#  9780.95,
#  9332.133333333333,
#  9364.483333333334,
#  9537.383333333333,
#  9181.316666666668,
#  9937.283333333333,
#  8810.7,
#  9048.8,
#  9598.466666666667,
#  9487.166666666666,
#  10112.283333333333,
#  8679.316666666668,
#  7736.966666666666,
#  8581.416666666666,
#  9744.966666666667,
#  8835.966666666667,
#  9886.7,
#  8044.55,
#  9265.816666666668,
#  8168.133333333333,
#  9110.183333333332,
#  7861.033333333334,
#  8530.066666666668,
#  9106.4,
#  9170.65,
#  8327.15,
#  8975.433333333332,
#  9649.25,
#  8807.066666666668,
#  9110.933333333332,
#  10310.7,
#  8628.65,
#  9671.9,
#  9507.783333333333,
#  9577.083333333334,
#  8345.383333333333,
#  9125.233333333334,
#  8837.933333333332,
#  10224.716666666667,
#  10404.783333333333,
#  9219.5]

# %% [markdown]
# # Distribution

# %%
sns.distplot(dataset["Purchase"])

# %%
sns.distplot(sample_means)

# %% [markdown]
# # Mean

# %%
sample_means
# Out:
# [9631.483333333334,
#  10077.583333333334,
#  10265.4,
#  8742.666666666666,
#  9714.283333333333,
#  9145.883333333333,
#  9694.133333333333,
#  9077.9,
#  9302.233333333334,
#  9780.95,
#  9332.133333333333,
#  9364.483333333334,
#  9537.383333333333,
#  9181.316666666668,
#  9937.283333333333,
#  8810.7,
#  9048.8,
#  9598.466666666667,
#  9487.166666666666,
#  10112.283333333333,
#  8679.316666666668,
#  7736.966666666666,
#  8581.416666666666,
#  9744.966666666667,
#  8835.966666666667,
#  9886.7,
#  8044.55,
#  9265.816666666668,
#  8168.133333333333,
#  9110.183333333332,
#  7861.033333333334,
#  8530.066666666668,
#  9106.4,
#  9170.65,
#  8327.15,
#  8975.433333333332,
#  9649.25,
#  8807.066666666668,
#  9110.933333333332,
#  10310.7,
#  8628.65,
#  9671.9,
#  9507.783333333333,
#  9577.083333333334,
#  8345.383333333333,
#  9125.233333333334,
#  8837.933333333332,
#  10224.716666666667,
#  10404.783333333333,
#  9219.5]

# %%
s_mean=np.mean(sample_means)

# %%
#mean of sample means
s_mean
# Out:
# 9225.764

# %%
#population mean
dataset["Purchase"].mean()
# Out:
# 9263.968712959126

# %% [markdown]
# # Variance

# %%
sample_means
# Out:
# [9631.483333333334,
#  10077.583333333334,
#  10265.4,
#  8742.666666666666,
#  9714.283333333333,
#  9145.883333333333,
#  9694.133333333333,
#  9077.9,
#  9302.233333333334,
#  9780.95,
#  9332.133333333333,
#  9364.483333333334,
#  9537.383333333333,
#  9181.316666666668,
#  9937.283333333333,
#  8810.7,
#  9048.8,
#  9598.466666666667,
#  9487.166666666666,
#  10112.283333333333,
#  8679.316666666668,
#  7736.966666666666,
#  8581.416666666666,
#  9744.966666666667,
#  8835.966666666667,
#  9886.7,
#  8044.55,
#  9265.816666666668,
#  8168.133333333333,
#  9110.183333333332,
#  7861.033333333334,
#  8530.066666666668,
#  9106.4,
#  9170.65,
#  8327.15,
#  8975.433333333332,
#  9649.25,
#  8807.066666666668,
#  9110.933333333332,
#  10310.7,
#  8628.65,
#  9671.9,
#  9507.783333333333,
#  9577.083333333334,
#  8345.383333333333,
#  9125.233333333334,
#  8837.933333333332,
#  10224.716666666667,
#  10404.783333333333,
#  9219.5]

# %%
np.var(sample_means)
# Out:
# 400318.36648177786

# %%
dataset["Purchase"].var()/k
# Out:
# 420519.7658433061

# %% [markdown]
# # STD

# %%
np.std(sample_means)
# Out:
# 632.7071727756671

# %%
dataset["Purchase"].std()/np.sqrt(k)
# Out:
# 648.4749539059362

# %% [markdown]
# # Confidence Interval

# %%
s_mean=np.mean(sample_means)

# %%
sns.distplot(sample_means)

# %%
s_std=np.std(sample_means)

# %% [markdown]
# # Confidence--90%

# %%
z=1.64

# %%
lower_limit=s_mean-(z*s_std)

# %%
lower_limit
# Out:
# 8188.1242366479055

# %%
upper_limit=s_mean+(z*s_std)

# %%
upper_limit
# Out:
# 10263.403763352093

# %%
lower_limit,upper_limit
# Out:
# (8188.1242366479055, 10263.403763352093)

# %%
#We are 90% confident that the mean of the population will be in interval range of 8188 to 10263

# %%
dataset["Purchase"].mean()
# Out:
# 9263.968712959126

# %% [markdown]
# # Confidence--95%

# %%
z=1.96

# %%
lower_limit=s_mean-(z*s_std)

# %%
lower_limit
# Out:
# 7985.657941359692

# %%
upper_limit=s_mean+(z*s_std)

# %%
upper_limit
# Out:
# 10465.870058640307

# %%
lower_limit,upper_limit
# Out:
# (7985.657941359692, 10465.870058640307)

# %%
#We are 95% confident that the mean of the population will be in interval range of 7985 to 10465

# %% [markdown]
# # Confidence--99%

# %%
z=2.576

# %%
lower_limit=s_mean-(z*s_std)

# %%
lower_limit
# Out:
# 7595.910322929881

# %%
upper_limit=s_mean+(z*s_std)

# %%
upper_limit
# Out:
# 10855.617677070117

# %%
lower_limit,upper_limit
# Out:
# (7595.910322929881, 10855.617677070117)

# %%
#We are 99% confident that the mean of the population will be in interval range of 7595 to 10855

# %%
min(sample_means),max(sample_means)
# Out:
# (7736.966666666666, 10404.783333333333)

# %% [markdown]
# 90-8188 to 10263 Narrorw
# 95-7985 to 10465 wide
# 99-7595 to 10855 wider

# %%
sns.distplot(sample_means)
