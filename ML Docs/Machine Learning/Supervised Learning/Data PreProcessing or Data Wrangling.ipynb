# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"F:\50_Startups.csv")

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11              NaN     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.isnull().any()
# Out:
# R&D Spend           True
# Administration     False
# Marketing Spend     True
# State               True
# Profit             False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# R&D Spend          1
# Administration     0
# Marketing Spend    1
# State              1
# Profit             0
# dtype: int64

# %% [markdown]
# ### Handling missing value

# %%
dataset.mean()
# Out:
# R&D Spend           74641.163673
# Administration     121344.639600
# Marketing Spend    210654.978367
# Profit             112012.639200
# dtype: float64

# %%
dataset.fillna(dataset.mean(),inplace=True)

# %%
dataset.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State               True
# Profit             False
# dtype: bool

# %%
dataset["State"].mode()[0]
# Out:
# 'California'

# %%
dataset["State"].fillna(dataset["State"].mode()[0],inplace=True)

# %%
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
dataset.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    210654.978367     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
dataset.sort_values(by="Profit",ascending=False,inplace=True)

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    210654.978367     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
dataset["R&D Spend"].ffill(inplace=True)

# %%
dataset.shape[0]
# Out:
# 50

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# R&D Spend          0.0
# Administration     0.0
# Marketing Spend    0.0
# State              0.0
# Profit             0.0
# dtype: float64

# %%
dataset.dropna(axis=0,inplace=True)

# %%
dataset.isnull().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
dataset.shape
# Out:
# (50, 5)

# %%
dataset.reset_index(drop=True,inplace=True)

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    210654.978367     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %%
dataset.boxplot()

# %%
sns.boxplot(dataset["Profit"])

# %%
q1=dataset["Profit"].describe()["25%"]

# %%
q3=dataset["Profit"].describe()["75%"]

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 49627.07499999998

# %%
l_b=q1-(1.5*iqr)

# %%
l_b
# Out:
# 15698.290000000023

# %%
u_b=q3+(1.5*iqr)

# %%
u_b
# Out:
# 214206.58999999997

# %%
dataset[dataset["Profit"]<l_b]
# Out:
#     R&D Spend  Administration  Marketing Spend       State   Profit
# 49        0.0        116983.8         45173.06  California  14681.4

# %%
dataset[dataset["Profit"]>u_b]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %% [markdown]
# ### Remove the outliers

# %%
dataset[(dataset["Profit"]<l_b) | (dataset["Profit"]>u_b)]
# Out:
#     R&D Spend  Administration  Marketing Spend       State   Profit
# 49        0.0        116983.8         45173.06  California  14681.4

# %%
outlier_index=dataset[(dataset["Profit"]<l_b)].index

# %%
dataset.drop(outlier_index,inplace=True)

# %%
sns.boxplot(dataset["Profit"])

# %% [markdown]
# ### Replace

# %%
sns.boxplot(dataset["Profit"])

# %%
l_b
# Out:
# 15698.290000000023

# %%
lower_outliers=dataset[dataset["Profit"]<l_b]["Profit"]

# %%
lower_outliers=lower_outliers.values

# %%
lower_outliers
# Out:
# array([], dtype=float64)

# %%
lower_outliers
# Out:
# array([], dtype=float64)

# %%
replace_dict={}.fromkeys(lower_outliers,l_b)

# %%
replace_dict
# Out:
# {}

# %%
dataset["Profit"].replace(replace_dict,inplace=True)

# %%
dataset["Profit"].mean()
# Out:
# 113998.99102040817

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.200000       136897.80    471784.100000    New York  192261.83
# 1   162597.700000       151377.59    443898.530000  California  191792.06
# 2   153441.510000       101145.55    407934.540000     Florida  191050.39
# 3   144372.410000       118671.85    383199.620000    New York  182901.99
# 4   142107.340000        91391.77    366168.420000     Florida  166187.94
# 5   131876.900000        99814.71    362861.360000    New York  156991.12
# 6   134615.460000       147198.87    127716.820000  California  156122.51
# 7   130298.130000       145530.06    323876.680000     Florida  155752.60
# 8   120542.520000       148718.95    311613.290000    New York  152211.77
# 9   123334.880000       108679.17    304981.620000  California  149759.96
# 10  101913.080000       110594.11    210654.978367     Florida  146121.95
# 11  100671.960000        91790.61    249744.550000  California  144259.40
# ...

# %% [markdown]
# ### Encoding Categorical text data

# %% [markdown]
# ##### One Hot Encoding

# %%
dataset=pd.get_dummies(dataset,columns=["State"])

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend     Profit  \
# 0   165349.200000       136897.80    471784.100000  192261.83
# 1   162597.700000       151377.59    443898.530000  191792.06
# 2   153441.510000       101145.55    407934.540000  191050.39
# 3   144372.410000       118671.85    383199.620000  182901.99
# 4   142107.340000        91391.77    366168.420000  166187.94
# 5   131876.900000        99814.71    362861.360000  156991.12
# 6   134615.460000       147198.87    127716.820000  156122.51
# 7   130298.130000       145530.06    323876.680000  155752.60
# 8   120542.520000       148718.95    311613.290000  152211.77
# 9   123334.880000       108679.17    304981.620000  149759.96
# 10  101913.080000       110594.11    210654.978367  146121.95
# 11  100671.960000        91790.61    249744.550000  144259.40
# 12   93863.750000       127320.38    249839.440000  141585.52
# 13   91992.390000       135495.07    252664.930000  134307.35
# ...

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend     Profit  \
# 0   165349.200000       136897.80    471784.100000  192261.83
# 1   162597.700000       151377.59    443898.530000  191792.06
# 2   153441.510000       101145.55    407934.540000  191050.39
# 3   144372.410000       118671.85    383199.620000  182901.99
# 4   142107.340000        91391.77    366168.420000  166187.94
# 5   131876.900000        99814.71    362861.360000  156991.12
# 6   134615.460000       147198.87    127716.820000  156122.51
# 7   130298.130000       145530.06    323876.680000  155752.60
# 8   120542.520000       148718.95    311613.290000  152211.77
# 9   123334.880000       108679.17    304981.620000  149759.96
# 10  101913.080000       110594.11    210654.978367  146121.95
# 11  100671.960000        91790.61    249744.550000  144259.40
# 12   93863.750000       127320.38    249839.440000  141585.52
# 13   91992.390000       135495.07    252664.930000  134307.35
# ...

# %% [markdown]
# #### Split Dependent and Independent Variables

# %%
dataset
# Out:
#         R&D Spend  Administration  Marketing Spend     Profit  \
# 0   165349.200000       136897.80    471784.100000  192261.83
# 1   162597.700000       151377.59    443898.530000  191792.06
# 2   153441.510000       101145.55    407934.540000  191050.39
# 3   144372.410000       118671.85    383199.620000  182901.99
# 4   142107.340000        91391.77    366168.420000  166187.94
# 5   131876.900000        99814.71    362861.360000  156991.12
# 6   134615.460000       147198.87    127716.820000  156122.51
# 7   130298.130000       145530.06    323876.680000  155752.60
# 8   120542.520000       148718.95    311613.290000  152211.77
# 9   123334.880000       108679.17    304981.620000  149759.96
# 10  101913.080000       110594.11    210654.978367  146121.95
# 11  100671.960000        91790.61    249744.550000  144259.40
# 12   93863.750000       127320.38    249839.440000  141585.52
# 13   91992.390000       135495.07    252664.930000  134307.35
# ...

# %%
#Independent Varaible Input
x=dataset.drop("Profit",axis=1)

# %%
x.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend  State_California  \
# 0  165349.20       136897.80        471784.10                 0
# 1  162597.70       151377.59        443898.53                 1
# 2  153441.51       101145.55        407934.54                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0

# %%
#Dependent Variable
y=dataset["Profit"]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# Name: Profit, dtype: float64

# %% [markdown]
# ### Split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x.shape
# Out:
# (49, 6)

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train.shape
# Out:
# (39, 6)

# %%
y_train.shape
# Out:
# (39,)

# %%
x_test.shape
# Out:
# (10, 6)

# %%
x_train
# Out:
#         R&D Spend  Administration  Marketing Spend  State_California  \
# 38   20229.590000        65947.93    185265.100000                 0
# 2   153441.510000       101145.55    407934.540000                 0
# 39   38558.510000        82982.09    174999.300000                 1
# 32   63408.860000       129219.61     46085.250000                 1
# 10  101913.080000       110594.11    210654.978367                 0
# 21   78389.470000       153773.43    299737.290000                 0
# 35   46014.020000        85047.44    205517.640000                 0
# 27   72107.600000       127864.55    353183.810000                 0
# 18   91749.160000       114175.79    294919.570000                 0
# 31   61136.380000       152701.92     88218.230000                 0
# 1   162597.700000       151377.59    443898.530000                 1
# 12   93863.750000       127320.38    249839.440000                 0
# 34   46426.070000       157693.92    210797.670000                 1
# ...

# %% [markdown]
# ### Building the SLR Model

# %%
from sklearn.linear_model import LinearRegression

# %%
#Init the Model
#Creating the instance of the model
lr_model=LinearRegression()

# %%
#Training the SLR ML Model
lr_model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8e83c60390fd> in <module>
#       1 #Training the SLR ML Model
# ----> 2 lr_model.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
#lr_model --Trained SLR model

# %% [markdown]
# #### Test the model

# %%
y_pred=lr_model.predict(x_test)

# %%
y_pred
# Out:
# array([89715.76498848, 56031.05821174, 53223.99931368, 40124.39112273,
#        44802.8226195 , 92522.82388655])

# %%
x_test
# Out:
#     YearsExperience
# 20              6.8
# 7               3.2
# 5               2.9
# 2               1.5
# 3               2.0
# 21              7.1

# %%
y_test
# Out:
# 20    91738.0
# 7     54445.0
# 5     56642.0
# 2     37731.0
# 3     43525.0
# 21    98273.0
# Name: Salary, dtype: float64

# %%
y_pred
# Out:
# array([89715.76498848, 56031.05821174, 53223.99931368, 40124.39112273,
#        44802.8226195 , 92522.82388655])

# %%
#a0--y-intercept --Constant
lr_model.intercept_
# Out:
# 26089.096632416724

# %%
#a1--Coef-Slope
lr_model.coef_
# Out:
# array([9356.86299354])
